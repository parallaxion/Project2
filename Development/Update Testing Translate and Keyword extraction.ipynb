# %%
import datetime as dt
import pandas as pd
import pymongo
import requests
import string

from config import API_KEY
from countries import countries, country_codes

from rake_nltk import Rake, Metric
from py_translator import Translator

# %%
#connect to mongodb
conn = 'mongodb://localhost:27017/top_headlines'
client = pymongo.MongoClient(conn)
# Declare the database
db = client["top_headlines"]
# Declare the collection
collection = db["countries_data"]

# %%
#get data
data = collection.find()

#get alphabet list
alphabet = list(string.ascii_lowercase)

# %%
#initialize countryWords dict and allWords string
countryWords = {}
allWords = ''

# %%
# ### reset data
collection = db["countries_data"]

for i in range(len(country_codes)):
    print(countries[i])
    badList = data[i]["articles"]
    goodList = []
    for j in range(60):
        goodList.append(badList[j])
    print(len(goodList))
#     print(collection)
    print(collection.find({"country": countries[i]}))
    collection.update_one({"country": countries[i]}, {"$set": {"articles": goodList}})
    print(len(data[i]["articles"]))
# Out:
# Argentina
# 60
# <pymongo.cursor.Cursor object at 0x0000022141B02DA0>
# 60
# Australia
# 60
# <pymongo.cursor.Cursor object at 0x0000022141EB5048>
# 60
# Austria
# 60
# <pymongo.cursor.Cursor object at 0x0000022141AF6E10>
# 60
# Belgium
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FB8240>
# 60
# Brazil
# 60
# <pymongo.cursor.Cursor object at 0x0000022141B05160>
# 60
# Bulgaria
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FC1F60>
# 60
# Canada
# 60
# <pymongo.cursor.Cursor object at 0x0000022141AF36D8>
# 60
# China
# 60
# <pymongo.cursor.Cursor object at 0x0000022141B05940>
# 60
# Colombia
# 60
# <pymongo.cursor.Cursor object at 0x0000022141AE0A20>
# 60
# Cuba
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FB85C0>
# 60
# Czech Republic
# 60
# <pymongo.cursor.Cursor object at 0x0000022141AE54E0>
# 60
# Egypt
# 60
# <pymongo.cursor.Cursor object at 0x0000022141AF30B8>
# 60
# France
# 60
# <pymongo.cursor.Cursor object at 0x0000022141EC1748>
# 60
# Germany
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FAC278>
# 60
# Greece
# 60
# <pymongo.cursor.Cursor object at 0x0000022141B05F98>
# 60
# Hong Kong
# 60
# <pymongo.cursor.Cursor object at 0x0000022141AE0BE0>
# 60
# Hungary
# 60
# <pymongo.cursor.Cursor object at 0x0000022141AF37B8>
# 60
# India
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FB64E0>
# 60
# Indonesia
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FACEF0>
# 60
# Ireland
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FB02E8>
# 60
# Israel
# 60
# <pymongo.cursor.Cursor object at 0x0000022141EC17B8>
# 60
# Italy
# 60
# <pymongo.cursor.Cursor object at 0x0000022141AE4828>
# 60
# Japan
# 60
# <pymongo.cursor.Cursor object at 0x0000022141B050F0>
# 60
# Latvia
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FC1E80>
# 60
# Lithuania
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FC7400>
# 60
# Malaysia
# 60
# <pymongo.cursor.Cursor object at 0x0000022141B05550>
# 60
# Mexico
# 60
# <pymongo.cursor.Cursor object at 0x0000022141EC17F0>
# 60
# Morocco
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FB0630>
# 60
# Netherlands
# 60
# <pymongo.cursor.Cursor object at 0x0000022141AF6E48>
# 60
# New Zealand
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FC7AC8>
# 60
# Nigeria
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FB0E48>
# 60
# Norway
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FB6748>
# 60
# Philippines
# 60
# <pymongo.cursor.Cursor object at 0x0000022141AE5208>
# 60
# Poland
# 60
# <pymongo.cursor.Cursor object at 0x0000022141AF30B8>
# 60
# Portugal
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FC7898>
# 60
# Romania
# 60
# <pymongo.cursor.Cursor object at 0x0000022141B05F98>
# 60
# Russia
# 60
# <pymongo.cursor.Cursor object at 0x0000022141AE0F60>
# 60
# Saudi Arabia
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FB0AC8>
# 60
# Serbia
# 60
# <pymongo.cursor.Cursor object at 0x0000022141AF35C0>
# 60
# Singapore
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FB6B00>
# 60
# Slovakia
# 60
# <pymongo.cursor.Cursor object at 0x0000022141B02C18>
# 60
# Slovenia
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FC7FD0>
# 60
# South Africa
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FB0EF0>
# 60
# South Korea
# 60
# <pymongo.cursor.Cursor object at 0x0000022141AF69B0>
# 60
# Sweden
# 60
# <pymongo.cursor.Cursor object at 0x0000022141AE40F0>
# 60
# Switzerland
# 60
# <pymongo.cursor.Cursor object at 0x0000022141B02160>
# 60
# Taiwan
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FC16D8>
# 60
# Thailand
# 60
# <pymongo.cursor.Cursor object at 0x0000022141B05390>
# 60
# Turkey
# 60
# <pymongo.cursor.Cursor object at 0x0000022141AE5F60>
# 60
# United Arab Emirates
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FC7710>
# 60
# Ukraine
# 60
# <pymongo.cursor.Cursor object at 0x0000022141AF6390>
# 60
# United Kingdom
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FB0780>
# 60
# United States of America
# 60
# <pymongo.cursor.Cursor object at 0x0000022141FB66D8>
# 60
# Venezuela
# 60
# <pymongo.cursor.Cursor object at 0x0000022141AE0400>
# 60

# %%
untranslated_countries = []
#for length of country_code list
for i in range(len(country_codes)):
    #visit news api
    query_url = f"https://newsapi.org/v2/top-headlines?country={country_codes[i]}&apiKey={API_KEY}"
    print("-----------------------------------------------------------")
    print(countries[i])
    print(query_url)
    #get response
    response = requests.get(query_url).json()

    #initialize countryWords dict and date
    countryWords[countries[i]] = ''
    date_list = []
    print("TITLES::::::")
    #for each article
    for article in response["articles"]:
        #set date and title
        date = article["publishedAt"][:10]
        date_list.append(date)
        title = article["title"].split(" - ")[0]
        print(title)
        #construct article dictionary
        articleDict = {"source": article["source"]["name"], 
                    "title": title, 
                    "url": article["url"], 
                    "date": date}
        #set the collection
        collection = db["countries_data"]
        #add article dict to countries data db
        collection.update_one({"country": countries[i]}, {"$push": {"articles": articleDict}})
        print("countries_data updated with " + countries[i] + " data.")
        #add title text to countryWords dict
        countryWords[countries[i]] = countryWords[countries[i]] + title + ' '
        ####end of articles loop
        ########################

    #untranslated string of article titles
    untranslated = countryWords[countries[i]]
#     print(untranslated)

#     try to translate
    try:
        translated = Translator().translate(text=untranslated, dest='en').text
        print("TRANSLATED::::::")
        print(countries[i])
        print(translated)

        #set the collection
        collection = db["countries_words"]
        #add translated string to countries_words collection
        collection.update_one({"country": countries[i]}, {"$set": {max(date_list): translated}}, upsert=True)
        print("countries_words updated with " + countries[i] + " words for " + max(date_list))
    except:
        untranslated_countries.append(countries[i])
        print(countries[i] + " failed to translate")

    #add translated string to string of all titles
    allWords = allWords + translated

    #set rake settings
    r = Rake(max_length=2, ranking_metric=Metric.WORD_DEGREE)
    #extract keywords with scores from translated string
    r.extract_keywords_from_text(translated)
    phrasesScores = r.get_ranked_phrases_with_scores()
    # print(phrasesScores)

    #initialize keywords dict
    keywords_dict = {"keywords": {}}
    #for index and keyword-score pair,
    for j, pair in enumerate(phrasesScores):

        #format pair into score and word
        pair = list(pair)
        score = pair[0]
        word = pair[1]

        #set special character list
        special_chars = ["-", "'", ":", ".", "’", "‘", "\\", "(", ")", "”", "“", "!", "?", "【", "】", "\""]
        # print(j, word)
        #if any special characters in word or word less than 2 characters,
        if any(x in word for x in special_chars) or len(word) < 2:
            # print(j)
            #remove word-score pair
            phrasesScores.pop(j)

        else:
            #for character in word
            for char in word:
                #if any letter matches character,
                if any(letter == char for letter in alphabet):
                    #word has letters, exit loop
                    hasLetters = True
                    break
                else:
                    hasLetters = False

            #if word has letters, 
            if hasLetters == True:
                #add word-score pair to keywords_dict
                keywords_dict["keywords"][word] = score

            #if word has no letters,
            else:
                #remove word-score pair
                # print(word + " has no letters")
                phrasesScores.pop(j)

    #set collection
    collection = db["countries_keywords"]
    #update countries_keywords collection with keywords_dict
    collection.update_one({"country": countries[i]}, {"$set": {"keywords": keywords_dict["keywords"]}}, upsert=True)
    ###end of country loop
    ######################
# Out:
# -----------------------------------------------------------
# Argentina
# https://newsapi.org/v2/top-headlines?country=ar&apiKey=89f29e52b3ff48fbbdb6b5439cf0fba4
# TITLES::::::
# Macri invitó a un K y a una diputada massista al viaje a la India, pero le dijeron que no
# countries_data updated with Argentina data.
# Marcelo D’Alessio “es el engranaje de algo más importante” | La abogada de Echebest habló de la denuncia...
# countries_data updated with Argentina data.
# Emiliano Sala: comenzó en Progreso el velorio del ex futbolista argentino del Nantes y el Cardiff
# countries_data updated with Argentina data.
# Francia vive un nuevo fin de semana de protestas de los chalecos amarillos
# countries_data updated with Argentina data.
# El descargo de Calu Rivero después de la escena de violación en "Campanas en la noche"
# countries_data updated with Argentina data.
# San Lorenzo pretende ganar por primera vez con Jorge Almirón ante Newell's: hora, TV y formaciones
# countries_data updated with Argentina data.
# Murió Bruno Ganz, el actor que encarnó a Adolf Hitler en La caída
# countries_data updated with Argentina data.
# El Vaticano expulsó a Theodore McCarrick, el ex cardenal estadounidense acusado de abusos sexuales
# countries_data updated with Argentina data.
# El mensaje de la chica que quedó parapléjica tras hacerse un piercing: "Tengan más cuidado cuando se hagan perforaciones"
# countries_data updated with Argentina data.
# ¡Dos argentinos en semis! Pella y Schwartzman, entre los cuatro mejores del ATP de Buenos Aires
# countries_data updated with Argentina data.
# Plan reelección: el ala política insiste en buscar acuerdos con el PJ para 2020
# countries_data updated with Argentina data.
# Histórico: la NASA intentará desviar un asteroide que impactaría en la Tierra
# countries_data updated with Argentina data.
# Un gigante chino se asoció con Radio Victoria para fabricar TV y celulares
# countries_data updated with Argentina data.
# Nicolás Maduro llamó a los militares a preparar un plan especial de despliegue ante las amenazas de Trump y Du
# countries_data updated with Argentina data.
# Filtrada: primeras imágenes de la nueva pick up mediana de Peugeot
# countries_data updated with Argentina data.
# Semana financiera: se aceleró la suba del dólar y la inflación interrumpió el ciclo de baja de tasas y la eufo
# countries_data updated with Argentina data.
# En medio del conflicto por la reelección, La Rioja difundió el cronograma electoral
# countries_data updated with Argentina data.
# ETS: las enfermedades de transmisión sexual que se manifiestan en lugares inesperados
# countries_data updated with Argentina data.
# Día Mundial del Cáncer Infantil: en Misiones se registraron hasta 50 casos en 2018 y el Ministro de Salud afirmó que la tasa de curación es del 75%
# countries_data updated with Argentina data.
# Cinco usos que podés darle a tu celular y probablemente desconocías
# countries_data updated with Argentina data.
# TRANSLATED::::::
# Argentina
# Macri invited a K and a Massista deputy to travel to India, but they told him that Marcelo D'Alessio is not "the gear of something more important" | Echebest's lawyer spoke about the complaint ... Emiliano Sala: the wake of the former Argentine footballer of Nantes and Cardiff began in Progreso France lives a new weekend of protests of the yellow vests The release of Calu Rivero after the scene of rape in "Bells at night" San Lorenzo pretends to win for the first time with Jorge Almirón before Newell's: time, TV and formations Bruno Ganz, the actor who played Adolf Hitler in The Fall The Vatican expelled Theodore McCarrick, the ex American cardinal accused of sexual abuse The message of the girl who became paraplegic after getting a piercing: "Be more careful when drilling." Two Argentines in semis! Pella and Schwartzman, among the four best of the Buenos Aires ATP Re-election plan: the political wing insists on seeking agreements with the PJ by 2020 Historic: NASA will try to divert an asteroid that would impact on Earth A Chinese giant teamed up with Radio Victoria to manufacture TV and cell phones Nicolás Maduro called on the military to prepare a special deployment plan against the threats of Trump and Du Filtrada: first images of Peugeot's new median pickup Financial Week: the dollar's rise accelerated and inflation interrupted the cycle of low rates and the eufo In the middle of the conflict for the re-election, La Rioja spread the electoral schedule ETS: the sexually transmitted diseases that are manifested in unexpected places World Childhood Cancer Day: in Missions were registered up to 50 cases in 2018 and the Minister of Health said that the cure rate is 75% Five uses that you can give to your cell phone and probably you were unaware
# countries_words updated with Argentina words for 2019-02-16
# -----------------------------------------------------------
# Australia
# https://newsapi.org/v2/top-headlines?country=au&apiKey=89f29e52b3ff48fbbdb6b5439cf0fba4
# TITLES::::::
# Heart age test: Check how old a heart is, via Heart Foundation and News Corp campaign
# countries_data updated with Australia data.
# Super Rugby 2019: Costly Foley miss haunts NSW Waratahs
# countries_data updated with Australia data.
# Donald Trump: Critics claim there is no ‘national emergency’
# countries_data updated with Australia data.
# Downfall star Bruno Ganz dies following battle with colon cancer
# countries_data updated with Australia data.
# 'Melrose Place' actress Amy Locane to serve more time for fatal DUI crash
# countries_data updated with Australia data.
# Sydney skies graced with sun halo
# countries_data updated with Australia data.
# Former Trump campaign chair Paul Manafort faces 19 years in jail
# countries_data updated with Australia data.
# 'I'm interested in growing more trees': PM announces $12.5m forestry boost
# countries_data updated with Australia data.
# Women motorcyclists rev up for Sheilas Shakedown
# countries_data updated with Australia data.
# Police provide update after 23-year-old man found dead at Mandurah property
# countries_data updated with Australia data.
# Three stores forced to close after 15 people contract salmonella from Vietnamese pork rolls
# countries_data updated with Australia data.
# NBA All-Star 2019
# countries_data updated with Australia data.
# Prince Harry and Meghan royal tour cost Australian taxpayers $411k
# countries_data updated with Australia data.
# Scott Morrison says people smugglers will ‘have a crack’ if Labor is elected
# countries_data updated with Australia data.
# OP Scores: Queensland's top graduates congratulated
# countries_data updated with Australia data.
# Emergency services hunt for missing swimmer near Ballina
# countries_data updated with Australia data.
# Men who can do more than 40 push-ups less likely to get heart disease
# countries_data updated with Australia data.
# Rare Super Mario Bros 'test launch' copy sells for $140,000 in record price for a video game
# countries_data updated with Australia data.
# Tamworth renamed ‘Tim Tamworth’ for national Tim Tam Day
# countries_data updated with Australia data.
# Quade Cooper impresses for Melbourne Rebels in Super Rugby win against ACT Brumbies
# countries_data updated with Australia data.
# TRANSLATED::::::
# Australia
# Heart age test: Check how old a heart is, via Heart Foundation and News Corp campaign Super Rugby 2019: Costly Foley miss haunts NSW Waratahs Donald Trump: Critics claim there is no ‘national emergency’ Downfall star Bruno Ganz dies following battle with colon cancer 'Melrose Place' actress Amy Locane to serve more time for fatal DUI crash Sydney skies graced with sun halo Former Trump campaign chair Paul Manafort faces 19 years in jail 'I'm interested in growing more trees': PM announces $12.5m forestry boost Women motorcyclists rev up for Sheilas Shakedown Police provide update after 23-year-old man found dead at Mandurah property Three stores forced to close after 15 people contract salmonella from Vietnamese pork rolls NBA All-Star 2019 Prince Harry and Meghan royal tour cost Australian taxpayers $411k Scott Morrison says people smugglers will ‘have a crack’ if Labor is elected OP Scores: Queensland's top graduates congratulated Emergency services hunt for missing swimmer near Ballina Men who can do more than 40 push-ups less likely to get heart disease Rare Super Mario Bros 'test launch' copy sells for $140,000 in record price for a video game Tamworth renamed ‘Tim Tamworth’ for national Tim Tam Day Quade Cooper impresses for Melbourne Rebels in Super Rugby win against ACT Brumbies
# countries_words updated with Australia words for 2019-02-16
# -----------------------------------------------------------
# Austria
# https://newsapi.org/v2/top-headlines?country=at&apiKey=89f29e52b3ff48fbbdb6b5439cf0fba4
# TITLES::::::
# Verhärtete Fronten in München: Merkel rechnet mit Trump ab
# countries_data updated with Austria data.
# Jet mit „Friends“-Stars Aniston und Cox musste notlanden
# countries_data updated with Austria data.
# Liechtenstein: Der Schatz des Fürsten
# countries_data updated with Austria data.
# Aufregung um Verleihung von Grazer Ehrenzeichen an Gabalier
# countries_data updated with Austria data.
# Schüsse in Wien-Meidling: Frau in Krankenhaus gestorben
# countries_data updated with Austria data.
# Aktuelle Studie weist die Vorteile von Vitamin-D auf den Blutzuckerspiegel nach
# countries_data updated with Austria data.
# Ski-WM live: Slalom der Damen in Aare
# countries_data updated with Austria data.
# Ski-WM: Liensberger lauert auf Slalommedaille
# countries_data updated with Austria data.
# Hirscher nach Silber: "Ich kann nicht immer einspringen
# countries_data updated with Austria data.
# Papst entlässt früheren Erzbischof, weiterer Missbrauchs-Verdachtsfall
# countries_data updated with Austria data.
# Schauspieler Bruno Ganz ist tot
# countries_data updated with Austria data.
# Ski-WM live: Der Stand im Damen-Slalom
# countries_data updated with Austria data.
# Notstand: Trump setzt auf totale Eskalation
# countries_data updated with Austria data.
# Helmut Kern: Im Porträt: Der neue Oberaufseher der Staatsholding
# countries_data updated with Austria data.
# Katy Perry und Orlando Bloom: Verlobung am Valentinstag
# countries_data updated with Austria data.
# Sonderermittler will lange Haft für Trumps Wahlkampfmanager
# countries_data updated with Austria data.
# Umfrage: FPÖ legt stark zu
# countries_data updated with Austria data.
# "Der Schiedsrichter war ein absoluter Skandal"
# countries_data updated with Austria data.
# Sicherungshaft: Kickl braucht Opposition
# countries_data updated with Austria data.
# DGAP-Stimmrechte: Wirecard AG (deutsch)
# countries_data updated with Austria data.
# TRANSLATED::::::
# Austria
# Hardened fronts in Munich: Merkel settles with Trump Jet with "Friends" stars Aniston and Cox had to make an emergency landing Liechtenstein: The treasure of the Prince excitement to award Grazer honor to Gabalier shots in Vienna-Meidling: Woman died in hospital Current study points the Benefits of vitamin D on the blood sugar level after World Ski Championships live: Slalom of the ladies in Aare Ski World Cup: Liensberger lurking on slalom medalist Hirscher after silver: "I can not always step in. Pope dismisses former archbishop, another suspected abuse actor Bruno Ganz dead Ski World Cup live: The stand in the women's slalom state of emergency: Trump relies on total escalation Helmut Kern: In the portrait: the new superintendent of the state holding Katy Perry and Orlando Bloom: Valentine's Day engagement Special investigator wants long imprisonment for Trump's campaign manager Poll: FPÖ lays strong to "The referee was an absolute scandal" Captive: Kickl needs opposition DGAP voting rights e: Wirecard AG (German)
# countries_words updated with Austria words for 2019-02-16
# -----------------------------------------------------------
# Belgium
# https://newsapi.org/v2/top-headlines?country=be&apiKey=89f29e52b3ff48fbbdb6b5439cf0fba4
# TITLES::::::
# Polémique autour du discours prononcé vendredi par Félix Tshisekedi
# countries_data updated with Belgium data.
# La victoire sur l'EI bientôt annoncée
# countries_data updated with Belgium data.
# Accident mortel à Rhode-St-Genèse: deux jeunes filles mineures sont décédées
# countries_data updated with Belgium data.
# Lestienne: "Je savais que j'allais retrouver mon niveau"
# countries_data updated with Belgium data.
# Connu pour son rôle d'Adolf Hitler dans «La Chute», l'acteur Bruno Ganz est décédé
# countries_data updated with Belgium data.
# Thierry Neuville au rallye de Suède: «Je vise la 2e place»
# countries_data updated with Belgium data.
# Trois voitures incendiées samedi à Nivelles
# countries_data updated with Belgium data.
# La NASA déclare Opportunity officiellement mort
# countries_data updated with Belgium data.
# Un générateur automatique de texte trop performant pour être public
# countries_data updated with Belgium data.
# La déclaration de David Hallyday concernant Johnny et les gilets jaunes (vidéo)
# countries_data updated with Belgium data.
# Comment l'armée américaine pourrait construire le mur de Donald Trump
# countries_data updated with Belgium data.
# L'accès au crédit hypothécaire s'annonce plus strict
# countries_data updated with Belgium data.
# Le gouvernement régularise la famille de la petite Mawda
# countries_data updated with Belgium data.
# Tendance L'OMS alerte sur une flambée de rougeole dans le monde
# countries_data updated with Belgium data.
# Cora va subir un grand lifting: votre magasin va s'offrir un gros coup de jeune (photo)
# countries_data updated with Belgium data.
# Découverte d'une araignée... à corne ? | Science | Actualités
# countries_data updated with Belgium data.
# Cinq morts et plusieurs policiers blessés dans une fusillade près de Chicago
# countries_data updated with Belgium data.
# Protection des données: l'amende astronomique que devra payer Facebook
# countries_data updated with Belgium data.
# La grand-mère de Nemmouche : "Je le renie"
# countries_data updated with Belgium data.
# L'effet inquiétant des boissons « light » sur les risques d'AVC
# countries_data updated with Belgium data.
# TRANSLATED::::::
# Belgium
# Polemic around the speech delivered Friday by Felix Tshisekedi The victory on the EI soon announced Deadly accident in Rhode-St-Genèse: two minor girls died Lestienne: "I knew that I was going to find my level" Known for his role of Adolf Hitler in "The Fall", the actor Bruno Ganz died Thierry Neuville at the rally of Sweden: "I aim for 2nd place" Three cars burned Saturday in Nivelles NASA declares Opportunity officially dead An automatic generator of text too powerful for to be public The statement of David Hallyday concerning Johnny and the yellow vests (video) How the US army could build the Donald Trump wall The access to the mortgage loan looks more strict The government regulates the family of the small Mawda Trend L WHO warns about a measles outbreak in the world Cora is going to undergo a major facelift: your store is going to have a big facelift (photo) Discovery of a spider ... horn? | Science | Five dead and several policemen wounded in a shooting near Chicago Data protection: the astronomical fine that will have to pay Facebook Nemmouche's grandmother: "I renounce it" The worrying effect of "light" drinks on the risks of stroke
# countries_words updated with Belgium words for 2019-02-16
# -----------------------------------------------------------
# Brazil
# https://newsapi.org/v2/top-headlines?country=br&apiKey=89f29e52b3ff48fbbdb6b5439cf0fba4
# TITLES::::::
# Onyx se reúne com Bolsonaro no Alvorada
# countries_data updated with Brazil data.
# Vasco e Fluminense se reúnem com Ferj para decidir sobre setor Sul do Maracanã para final
# countries_data updated with Brazil data.
# Coletes amarelos voltam às ruas de Paris no 14º fim de semana de protestos
# countries_data updated with Brazil data.
# Corpo de rapaz que morreu após ser imobilizado em supermercado do Rio por vigilante é enterrado
# countries_data updated with Brazil data.
# Boechat morreu em decorrência de politraumatismo, aponta laudo
# countries_data updated with Brazil data.
# Ator Bruno Ganz, famoso por interpretar Hitler, morre aos 77 anos
# countries_data updated with Brazil data.
# Vinicius Jr. é capa de jornal na Espanha e recebe status de "intocável"
# countries_data updated with Brazil data.
# Quatro municípios do Ceará registram chuvas acima de 100 milímetros
# countries_data updated with Brazil data.
# Presidente da Petrobras quer vender quase tudo no refino
# countries_data updated with Brazil data.
# Americano deixa de ser cardeal e padre por abuso sexual
# countries_data updated with Brazil data.
# 'O desleal viverá esperando o mundo desabar na sua cabeça', diz mensagem publicada por Bebianno
# countries_data updated with Brazil data.
# A montadora que continuar vendendo carros e não milhagem vai quebrar, diz fundador do Waze
# countries_data updated with Brazil data.
# Os planos de Carille para recuperar Clayson e ter velocidade no Timão
# countries_data updated with Brazil data.
# Ex-prefeito morre com suspeita de dengue hemorrágica em Guaraçaí
# countries_data updated with Brazil data.
# Rízia fica sem graça durante conversa sobre sexo na madrugada
# countries_data updated with Brazil data.
# Tem voo no fim de semana? Fique atento ao fim do horário de verão
# countries_data updated with Brazil data.
# Eleição na Nigéria é adiada horas antes do início da votação
# countries_data updated with Brazil data.
# Jornalista rebate declaração de Abel: "Acha que tem que ser o inverso"
# countries_data updated with Brazil data.
# Galaxy S10: O que esperar do novo top de linha da Samsung?
# countries_data updated with Brazil data.
# Ex-funcionário invade empresa e mata 5 nos arredores de Chicago
# countries_data updated with Brazil data.
# TRANSLATED::::::
# Brazil
# Onyx meets with Bolsonaro in the Alvorada Vasco and Fluminense meet with Ferj to decide on South sector of the Maracanã for the end Yellow vests return to the streets of Paris in the 14th weekend of protests Body of boy who died after being immobilized in supermarket of Rio by The city of Ceará, Brazil, is one of the most important cities in the country, and it is known as the "untouchable" state of Ceará. millimeters President of Petrobras wants to sell almost everything in the refining American ceases to be cardinal and priest for sexual abuse 'The disloyal will live waiting for the world to fall into his head', says message published by Bebianno The automaker that continue selling cars and not mileage will break, says founder of Waze Carille plans to recover Clayson and have speed in Timão Former mayor dies with suspicion of dengue he Rizia is embarrassed during sex talk at dawn Do you have a weekend flight? Stay tuned for the end of summer time Election in Nigeria is delayed hours before the start of the vote Abel's journalist rebuttal statement: "Think it has to be the reverse" Galaxy S10: What to expect from the new top of the line Samsung? Former employee invades business and kills 5 on Chicago outskirts
# countries_words updated with Brazil words for 2019-02-16
# -----------------------------------------------------------
# Bulgaria
# https://newsapi.org/v2/top-headlines?country=bg&apiKey=89f29e52b3ff48fbbdb6b5439cf0fba4
# TITLES::::::
# Редовен ли бе голът на Ради Василев във вратата на ЦСКА?
# countries_data updated with Bulgaria data.
# Адвокат: Митьо Очите кърви. Викат "Бърза помощ" (Обновена)
# countries_data updated with Bulgaria data.
# Локомотивът от Хитрино е водил дерайлиралия влак в Пловдив
# countries_data updated with Bulgaria data.
# Цветанов за ДПС и преференциите. Нинова: Лъсна истината
# countries_data updated with Bulgaria data.
# Футболно клъцни-срежи: кой е отборът, който спря "Лудогорец"
# countries_data updated with Bulgaria data.
# Голям пожар в София
# countries_data updated with Bulgaria data.
# Живеещи до гарата в Пловдив: Щяхме да изгорим, докато спим
# countries_data updated with Bulgaria data.
# Борисов се срещна с Майк Пенс
# countries_data updated with Bulgaria data.
# Хитър злосторник обира банкомати… с дъвка
# countries_data updated with Bulgaria data.
# Брад Пит продуцира документален филм за Крис Корнел
# countries_data updated with Bulgaria data.
# "Амазон" се отказа от централата в Ню Йорк след протести на местните хора
# countries_data updated with Bulgaria data.
# НАТО и Русия не се разбраха
# countries_data updated with Bulgaria data.
# Израел Хоровиц пред “24 часа”: Открих, че съм болен от рак
# countries_data updated with Bulgaria data.
# Осуетиха терористично нападение в Северна Македония
# countries_data updated with Bulgaria data.
# Юве загря за Атлетико с победа на ходом + ВИДЕО
# countries_data updated with Bulgaria data.
# Доналд Тръмп изпълни заканата си и обяви извънредно положение заради стената
# countries_data updated with Bulgaria data.
# Брентът достигна рекордна за годината цена
# countries_data updated with Bulgaria data.
# Продажбите на нови коли продължават да падат
# countries_data updated with Bulgaria data.
# Поправките в Изборния кодекс: няколко смущаващи факта
# countries_data updated with Bulgaria data.
# Василис Карас в ексклузивно интервю преди прощалния си концерт
# countries_data updated with Bulgaria data.
# TRANSLATED::::::
# Bulgaria
# Has Radi Vassilev's goal scored in the goal of CSKA? Lawyer: Mythy Eyes bleeds. Call "Emergency" (Renewed) The Hitrino locomotive led the derailed train in Plovdiv Tsvetanov for the MRF and the preferences. Ninova: The Lost Truth Football Club: What is the Team Who Stops Ludogorets Big Fire in Sofia Living By The Railway Station in Plovdiv: We Were To Burn While We Sleep Borisov Meets With Mike Pens Hidden Evil Knocks ATMs ... With Chewing Brad Pitt Produced a documentary about Chris Cornell Amazon dropped out of New York headquarters following protests by local people NATO and Russia did not understand Israeli Horowitz in 24 hours: I found myself cancerous I suffered a terrorist attack on northern Macedonia Ju Atletico with victory on walk + VIDEO Don LD Trump carry out his threat and declares emergency over the wall Brent reached a record price for the year Sales of new cars continue to fall amendments to the Electoral Code, some disturbing fact Vasilis Karras in an exclusive interview before the farewell concert
# countries_words updated with Bulgaria words for 2019-02-16
# -----------------------------------------------------------
# Canada
# https://newsapi.org/v2/top-headlines?country=ca&apiKey=89f29e52b3ff48fbbdb6b5439cf0fba4
# TITLES::::::
# Vatican defrocks former U.S. cardinal over sex abuse
# countries_data updated with Canada data.
# Illinois man being fired from job fatally shoots five workers
# countries_data updated with Canada data.
# NEW Canopy Growth Reports $83-Million in Revenue February 16, 2019
# countries_data updated with Canada data.
# Liberals risk 'brand damage' over Wilson-Raybould controversy, says former Martin government official
# countries_data updated with Canada data.
# Talbot trade signals Oilers’ focus on clearing salary
# countries_data updated with Canada data.
# News Roundup: How to get a 725-hp F-150 for $53000
# countries_data updated with Canada data.
# The cars of the 2019 Toronto auto show get their close-ups
# countries_data updated with Canada data.
# Trump said he’d be sued over his emergency declaration. Enter three landowners from the Texas border
# countries_data updated with Canada data.
# Jennifer Jones eyes history as Scotties gets underway in Nova Scotia
# countries_data updated with Canada data.
# 21 Savage 'wasn't hiding' being British, feared deportation
# countries_data updated with Canada data.
# Next-level Matthews returns to his hockey roots
# countries_data updated with Canada data.
# Health officials confirm measles outbreak in Vancouver after 9th case identified
# countries_data updated with Canada data.
# Payless ShoeSource to close remaining 2,100 stores in U.S.
# countries_data updated with Canada data.
# NFL now paying for Kaepernick to shut up and go away
# countries_data updated with Canada data.
# 2 men questioned about alleged attack on actor Jussie Smollett released without charge
# countries_data updated with Canada data.
# U.K. report says former B.C. premier Gordon Campbell under investigation for alleged assault
# countries_data updated with Canada data.
# Keith Gerein: Clumsy NDP effort to vilify Jason Kenney carries high risk of backfire
# countries_data updated with Canada data.
# WARMINGTON: Brampton girl's life stolen on her 11th birthday
# countries_data updated with Canada data.
# NASA Opportunity last message: What were the final heartbreaking words of the Mars rover?
# countries_data updated with Canada data.
# Washington lawmakers advance limits on vaccine exemptions
# countries_data updated with Canada data.
# TRANSLATED::::::
# Canada
# Vatican defrocks former U.S. cardinal over sex abuse Illinois man being fired from job fatally shoots five workers NEW Canopy Growth Reports $83-Million in Revenue February 16, 2019 Liberals risk 'brand damage' over Wilson-Raybould controversy, says former Martin government official Talbot trade signals Oilers’ focus on clearing salary News Roundup: How to get a 725-hp F-150 for $53000 The cars of the 2019 Toronto auto show get their close-ups Trump said he’d be sued over his emergency declaration. Enter three landowners from the Texas border Jennifer Jones eyes history as Scotties gets underway in Nova Scotia 21 Savage 'wasn't hiding' being British, feared deportation Next-level Matthews returns to his hockey roots Health officials confirm measles outbreak in Vancouver after 9th case identified Payless ShoeSource to close remaining 2,100 stores in U.S. NFL now paying for Kaepernick to shut up and go away 2 men questioned about alleged attack on actor Jussie Smollett released without charge U.K. report says former B.C. premier Gordon Campbell under investigation for alleged assault Keith Gerein: Clumsy NDP effort to vilify Jason Kenney carries high risk of backfire WARMINGTON: Brampton girl's life stolen on her 11th birthday NASA Opportunity last message: What were the final heartbreaking words of the Mars rover? Washington lawmakers advance limits on vaccine exemptions
# countries_words updated with Canada words for 2019-02-16
# -----------------------------------------------------------
# China
# https://newsapi.org/v2/top-headlines?country=cn&apiKey=89f29e52b3ff48fbbdb6b5439cf0fba4
# TITLES::::::
# 「傳統文化是珍寶」 公司老闆讚神韻非凡
# countries_data updated with China data.
# 先南下再西游，蚂蚁金服的海外投资如何开花？
# countries_data updated with China data.
# 铁树终开花 迪巴拉与C罗首次携手取得进球
# countries_data updated with China data.
# 朝鲜举办活动纪念金正日诞辰77周年-中新网
# countries_data updated with China data.
# 福州一自建民房意外倒塌：15人获救送医民众回忆如地震一般-中新网视频
# countries_data updated with China data.
# 西班牙人客战瓦伦西亚大名单：武磊领衔有望首发
# countries_data updated with China data.
# 司机不赚钱滴滴喊巨亏，不差钱的滴滴到底把钱烧哪了？
# countries_data updated with China data.
# 特朗普：美中谈判非常顺利 暗示或延长谈判大限
# countries_data updated with China data.
# 【国际锐评】习近平首见美方代表两国元首引领经贸“加减法”
# countries_data updated with China data.
# 国际观察：慕安会凸显跨大西洋矛盾-新华网
# countries_data updated with China data.
# 习近平会见美国贸易代表莱特希泽和财政部长姆努钦
# countries_data updated with China data.
# 全明星新秀赛美国队击败世界队-新华网体育
# countries_data updated with China data.
# “中国冬奥冠军之乡”七台河的“冠军馆”16日开馆-中新网
# countries_data updated with China data.
# 【央视快评】坚定不移走中国特色社会主义法治道路_新闻频道
# countries_data updated with China data.
# 2月16日江苏省外三元生猪市场行情动态- 价为,外三元,上涨了,跌了,KG
# countries_data updated with China data.
# 中国人民银行：1月份人民币贷款创单月历史新高_国内新闻
# countries_data updated with China data.
# 《流浪地球》之后，中国电影工业还要迈几道坎？
# countries_data updated with China data.
# 奥斯卡反悔：最佳摄影等4个奖项颁奖将直播播出|奥斯卡|颁奖|广告时间_新浪娱乐_新浪网
# countries_data updated with China data.
# 习近平的2019·一月：六个金句看新年开局_新民时政
# countries_data updated with China data.
# 旧伤未愈又添新伤股民遭遇“业绩暴雷股+解禁”
# countries_data updated with China data.
# TRANSLATED::::::
# China
# "Traditional culture is a treasure." The boss of the company praises the extraordinary charm. How about the overseas investment of Ant Financial? Iron Tree finally blossoms Dibara and C Ronaldo to join hands for the first time to score goals North Korea to hold events to commemorate the 77th anniversary of Kim Jong Il's birth - Zhongxin.com Fuzhou, a self-built house accident collapsed: 15 people were rescued and sent to the public to recall the earthquake like the earthquake - Chinanews.com Video Spain's guest war in Valencia's big list: Wu Lei led the prospective starter driver does not make money, screaming huge losses, not bad money in the end to burn the money? Trump: US-China negotiations very smoothly suggest or extend the negotiation limit [International Sharp Review] Xi Jinping first saw the US side on behalf of the two heads of state to lead the economic and trade "addition and subtraction" International observation: Muan will highlight the transatlantic contradiction - Xinhuanet Xi Jinping meets the United States Trade Representative Wright Heze and Finance Minister Mnuchin All-Star rookie US team beat the world team - Xinhuanet Sports "China Winter Olympics Champion" Qitaihe "Champion Pavilion" opened on the 16th - Zhongxin Net [CCTV Quick Comment] Unswervingly follow the path of socialist rule of law with Chinese characteristics _ News Channel February 16 Jiangsu Province Sanyuan live pig market dynamics - the price is, the external ternary, rose, fell, KG People's Bank of China: January Renminbi loans hit a new high in a single month _ After the domestic news "Wandering Earth", how many hurdles does the Chinese film industry have? Oscar repentance: 4 awards for best photography will be broadcast live | Oscar | Awards | Advertising time _ Sina Entertainment _ Sina.com Xi Jinping's 2019 January: six golden sentences to see the new year's opening _ Xinmin's old politics and unhealed Adding new injured stockholders suffered "performance tyrants + lifting ban"
# countries_words updated with China words for 2019-02-16
# -----------------------------------------------------------
# Colombia
# https://newsapi.org/v2/top-headlines?country=co&apiKey=89f29e52b3ff48fbbdb6b5439cf0fba4
# TITLES::::::
# Tour Colombia 2019 en vivo: Etapa 5 en directo
# countries_data updated with Colombia data.
# NOTICIAS: Maduro no se detiene y ordena militarizar frontera con Colombia
# countries_data updated with Colombia data.
# ¿Por qué un joven fue multado con $883 mil por comprar una empanada en la calle?
# countries_data updated with Colombia data.
# Expectativa por concierto 'Ayuda y Libertad' por Venezuela
# countries_data updated with Colombia data.
# Bogotá, en primer fin de semana con pico y placa por culpa de polución
# countries_data updated with Colombia data.
# Yo soy Betty, la fea | Capítulo 9 – 15 de febrero
# countries_data updated with Colombia data.
# Excompañero de Emiliano Sala en Francia pidió no jugar para ir a su entierro
# countries_data updated with Colombia data.
# Condenan a exalcalde de Bogotá Samuel Moreno a 39 años de cárcel
# countries_data updated with Colombia data.
# Ocho síntomas de alerta del cáncer infantil
# countries_data updated with Colombia data.
# Galaxy Tab S5e: la nueva tableta ‘barata’ y delgada de Samsung
# countries_data updated with Colombia data.
# Emergencia ambiental en Bogotá: ¿Vale la pena que guarde su carro o moto?
# countries_data updated with Colombia data.
# La Academia echa reversa y transmitirá todos los premios Óscar
# countries_data updated with Colombia data.
# Mujer apuñaló a su esposo en plena calle y luego lo llevó al hospital
# countries_data updated with Colombia data.
# Cristiano anota de nuevo y Juventus vuelve a ganar en la Serie A
# countries_data updated with Colombia data.
# HuaWeek: estas son algunas de las mejores ofertas que encontrarás
# countries_data updated with Colombia data.
# Petróleo continúa racha de ganancias en los mercados internacionales
# countries_data updated with Colombia data.
# “California te verá en los juzgados”: Gobernador a Trump por emergencia nacional
# countries_data updated with Colombia data.
# AP: EEUU enviará avión militar con ayudas humanitarias a Venezuela
# countries_data updated with Colombia data.
# Pico y Placa se extiende a fines de semana por contaminación en Bogotá
# countries_data updated with Colombia data.
# “Ya lo sentíamos”: familia de Mara, cuando ella les confesó que era una mujer
# countries_data updated with Colombia data.
# TRANSLATED::::::
# Colombia
# Tour Colombia 2019 live: Stage 5 live NEWS: Maduro does not stop and orders to militarize border with Colombia Why was a young man fined $ 883 thousand for buying a pie on the street? Expectation for concert 'Help and Freedom' for Venezuela Bogotá, in first weekend with peak and plate because of pollution I am Betty, the ugly | Chapter 9 - February 15 Ex-companion of Emiliano Sala in France asked not to play to go to his burial Bogota's ex-mayor Samuel Moreno is sentenced to 39 years in prison Eight symptoms of childhood cancer alert Galaxy Tab S5e: the new 'cheap' tablet thin of Samsung Environmental Emergency in Bogota: Is it worth it to keep your car or motorcycle? The Academy reverses and will broadcast all the awards Óscar Mujer stabbed her husband in the street and then took him to the hospital Cristiano scores again and Juventus returns to win in Serie A HuaWeek: these are some of the best deals you will find Oil continues win streak in international markets "California will see you in court": Governor to Trump for national emergency AP: US will send military plane with humanitarian aid to Venezuela Pico y Placa is spread over weekends due to pollution in Bogota "We already felt it ": Mara's family, when she confessed to them that she was a woman
# countries_words updated with Colombia words for 2019-02-16
# -----------------------------------------------------------
# Cuba
# https://newsapi.org/v2/top-headlines?country=cu&apiKey=89f29e52b3ff48fbbdb6b5439cf0fba4
# TITLES::::::
# Cubanos que cumplen misión en el exterior votan por la nueva Constitución (+ Fotos)
# countries_data updated with Cuba data.
# ONU sigue de cerca la situación en Haití
# countries_data updated with Cuba data.
# Maduro califica de exitosos ejercicios militares en Venezuela
# countries_data updated with Cuba data.
# La NASA prepara el primer vuelo de un avión con motor eléctrico
# countries_data updated with Cuba data.
# Tambores japoneses retumban en Feria del Libro de La Habana
# countries_data updated with Cuba data.
# Un ex dictador, un magnate sospechado y la amenaza de Boko Haram: la gran potencia africana elige presidente
# countries_data updated with Cuba data.
# Suben precios petroleros en el cierre semanal de mercados
# countries_data updated with Cuba data.
# Cuba vence 11x6 a estrellas de la liga salvadoreña de béisbol
# countries_data updated with Cuba data.
# Taekwondoca Glenhis Hernández está lista para enfrentar la cita multideportiva Lima-2019
# countries_data updated with Cuba data.
# Poniendo el balón en su lugar
# countries_data updated with Cuba data.
# Nicolás Maduro llamó a los militares a preparar un plan especial de despliegue ante las amenazas de Trump y Du
# countries_data updated with Cuba data.
# Darán a conocer este sábado en Cienfuegos los premios del Festival del Monólogo Latinoamericano
# countries_data updated with Cuba data.
# Audio: “Estamos soñando, pero hay que cosas que se pueden ir haciendo”
# countries_data updated with Cuba data.
# Nubia Alpha: tecnología móvil del futuro (+ Video)
# countries_data updated with Cuba data.
# El superávit comercial de la zona del euro se redujo en 2018
# countries_data updated with Cuba data.
# El precio del petróleo de Texas sube un 2,17% hasta 55,59 dólares el barril
# countries_data updated with Cuba data.
# Angélica Cruz, exmujer de Nicky Jam, exhibe sus curvas en un ceñido vestido rojo
# countries_data updated with Cuba data.
# Stalin González: Gobierno de transición incluirá a chavistas y militares
# countries_data updated with Cuba data.
# Recibirá Cuba a Duquesa de Cornualles y Príncipe de Gales
# countries_data updated with Cuba data.
# Planeta enano Ceres tuvo agua bajo su superficie, según estudio
# countries_data updated with Cuba data.
# TRANSLATED::::::
# Cuba
# Cubans who complete mission abroad vote for the new Constitution (+ photos) UN follows closely the situation in Haiti Maduro qualifies for successful military exercises in Venezuela NASA prepares the first flight of an electric-powered aircraft Japanese drums boom at Feria del Book of Havana A former dictator, a suspected magnate and the threat of Boko Haram: the great African power elects president Oil prices rise in the weekly closing of markets Cuba beats 11x6 stars of the Salvadoran baseball league Taekwondoca Glenhis Hernández is ready for face the multi-sporting event Lima-2019 Putting the ball in its place Nicolás Maduro called on the military to prepare a special deployment plan in the face of the threats of Trump and Du Darán on Saturday in Cienfuegos to recognize the awards of the Latin American Audio Monologue Festival: " We are dreaming, but there are things that can be done "Nubia Alpha: mobile technology of the future (+ Video) The trade surplus of the euro area was reduced in 2018 The price of Texas oil rose by 2.17% to 55.59 dollars a barrel Angélica Cruz, Nicky Jam's ex-wife, exhibits her curves in a tight dress red Stalin González: Transitional government will include Chavistas and soldiers Cuba will receive Duchess of Cornwall and Prince of Wales Dwarf planet Ceres had water under its surface, according to study
# countries_words updated with Cuba words for 2019-02-16
# -----------------------------------------------------------
# Czech Republic
# https://newsapi.org/v2/top-headlines?country=cz&apiKey=89f29e52b3ff48fbbdb6b5439cf0fba4
# TITLES::::::
# Shiffrinová je počtvrté v řadě světovou šampionkou ve slalomu
# countries_data updated with Czech Republic data.
# Huawei neškodí, ignorujte Washington, radil čínský komunista v Mnichově
# countries_data updated with Czech Republic data.
# Ochladí se ještě? Meteorologové vydali předpověď na měsíc
# countries_data updated with Czech Republic data.
# Pražský hotel Holiday Inn lhal o původu hovězího masa
# countries_data updated with Czech Republic data.
# Evropa musí ukončit dohodu s Íránem, zahřímal viceprezident USA Pence v Mnichově
# countries_data updated with Czech Republic data.
# Zemřel herec Bruno Ganz, známý byl hlavně jako Hitler z Pádu třetí říše
# countries_data updated with Czech Republic data.
# Do vedení ANO se může dostat Vondráček i Macura, do vlády Vokřál, tvrdí Faltýnek
# countries_data updated with Czech Republic data.
# V nemocnici zemřela jednadevadesátiletá žena, kterou ve středu napadla doga
# countries_data updated with Czech Republic data.
# Dodávka u Krušovic přejela do protisměru, po střetu s osobním autem čtyři zranění
# countries_data updated with Czech Republic data.
# Na Dole ČSM opět hořelo, událost se tentokrát obešla bez obětí
# countries_data updated with Czech Republic data.
# První slova Zdeňka (34) z Výměny po bouračce: Probudil se z kómatu a neměl nohy!
# countries_data updated with Czech Republic data.
# Návrat do Pchjongčchangu s úspěšnou tečkou. Ledecká vyhrála závod SP na snowboardu
# countries_data updated with Czech Republic data.
# Osm aut do 3000 korun se pokusí objet Českou republiku
# countries_data updated with Czech Republic data.
# 30 let od pádu jejich režimu. Komunisté se pokouší diktovat českou zahraniční politiku
# countries_data updated with Czech Republic data.
# Trumpův stav nouze mohou zablokovat soudy. Chce využít peníze na armádní stavby | Svět
# countries_data updated with Czech Republic data.
# Ano, natočili jsme video o pozvánce na tiskovku. Je boží a Galaxy S10 bude také*
# countries_data updated with Czech Republic data.
# Mela mezi prohlížeči: Webu může začít vládnout jen jediné vykreslovací jádro
# countries_data updated with Czech Republic data.
# Pražský magistrát odmítl exhumaci Zdeny Mašínové starší. Neví, kde leží ostatky
# countries_data updated with Czech Republic data.
# Airbus končí s výrobou obřího letounu A380 superjumbo. Je příliš drahý a aerolinky radši pořizují menší stroje
# countries_data updated with Czech Republic data.
# Teplice
# countries_data updated with Czech Republic data.
# TRANSLATED::::::
# Czech Republic
# Shiffrin is the Fourth World Champion in Huawei Slalom, Do not Fail, Ignore Washington, Advised by Chinese Communist in Munich Cooling yet? Meteorologists have released a forecast for the month Prague hotel Holiday Inn lied about the origin of beef Europe has to end the deal with Iran, warmed by US Vice President Pence in Munich Died actor Bruno Ganz, known mainly as Hitler from Fall of the Third Reich In the leadership YES can get Vondráček i Macura , to the government Vokřál, says Faltýnek In the hospital, a woman aged fifty died in the hospital, donating Dodáka to Krušovice on Wednesday, after the collision with a personal car four injuries On the floor of ČSM again burned, the event went round without sacrifice The first words of Zdenek (34) from the Courage Replacement: He woke up from the coma and had no legs! Return to Pyongyang with a successful touch. Ledecká won SP on the snowboard Eight cars to 3000 crowns will try to fly the Czech Republic 30 years after the fall of their regime. Communists attempt to dictate Czech foreign policy Trump's state of emergency may block judgments. He wants to use money for army constructions World Yes, we filmed a video about a press invitation. It is God and Galaxy S10 will also * Mela among the browsers: The Web can only start to rule a single rendering core The Prague City Hall has refused to exhume Zdena Masin's elders. He does not know where the remains of Airbus ends with the production of the giant A380 superjumbo. It is too expensive and the airline will rather make smaller machines in Teplice
# countries_words updated with Czech Republic words for 2019-02-16
# -----------------------------------------------------------
# Egypt
# https://newsapi.org/v2/top-headlines?country=eg&apiKey=89f29e52b3ff48fbbdb6b5439cf0fba4
# TITLES::::::
# في خطاب رسمي.. الجونة يتحفظ على تعيين حكام عرب بمواجهة بيراميدز
# countries_data updated with Egypt data.
# بعد الأزمة الأخيرة.. جماهير إنتر ميلان تعتدي على سيارة زوجة إيكاردي
# countries_data updated with Egypt data.
# نانسى عجرم لإليسا: أتمنى لكى شفاء عاجل.. والأخيرة تطمئن جمهورها
# countries_data updated with Egypt data.
# أسعار الذهب اليوم السبت 16 -2-2019 فى الأسواق
# countries_data updated with Egypt data.
# بالصور| "يا خراب بيتك".. تفاصيل سرقة محل مجوهرات بحدائق الأهرام
# countries_data updated with Egypt data.
# بيلد: كومان سيكون جاهزا لمواجهة ليفربول
# countries_data updated with Egypt data.
# السيسي يحرج رئيس مؤتمر ميونخ
# countries_data updated with Egypt data.
# تأجيل الحكم فى استئناف داليا البحيرى على حكم حبسها عامين لـ 6 أبريل
# countries_data updated with Egypt data.
# المتحدث العسكري: القضاء على 7 تكفيريين بشمال سيناء
# countries_data updated with Egypt data.
# أسعار الذهب تصعد عالميًا لأعلى مستوى في أسبوعين
# countries_data updated with Egypt data.
# التايمز: عروس "الدولة الإسلامية" تخاف على طفلها وتكشف عن حبها لزوجها الجهادي
# countries_data updated with Egypt data.
# تشكيل الأهلي المتوقع.. ناصر ماهر أساسيا أمام الانتاج الحربي
# countries_data updated with Egypt data.
# 10 طرق تحمى بها خلاياك من التحول للسرطان.. تعرف عليها
# countries_data updated with Egypt data.
# مصرع المتهم بـ«اقتحام مسجد أسيوط» في تبادل إطلاق نيران مع الشرطة
# countries_data updated with Egypt data.
# رياح وأمطار وبرودة شديدة ليلًا.. الأرصاد تعلن تفاصيل طقس السبت
# countries_data updated with Egypt data.
# اليوم.. الحكومة تُطلق حملة الكشف المبكر عن السمنة والتقزم بالمدارس
# countries_data updated with Egypt data.
# سامسونج تكشف عن حاسبها اللوحي Galaxy Tab S5e بسماكة 5.5 ميليمترات فقط
# countries_data updated with Egypt data.
# 01:02 حظك اليوم.. توقعات الأبراج السبت 16 فبراير 2019
# countries_data updated with Egypt data.
# مفاجأة.. فريق اغتيال خاشقجي اشترى 32 كجم من اللحم النيء بعد الجريمة
# countries_data updated with Egypt data.
# حظك اليوم السبت 16/2/2019 برج الاسد على الصعيد المهنى والصحى والعاطفى.. حظك جيد هذه الأيام
# countries_data updated with Egypt data.
# TRANSLATED::::::
# Egypt
# In an official speech .. El Gouna reservations on the appointment of Arab rulers to confront Pyramids after the recent crisis .. Inter Milan fans attacked the car of the wife of ICARDA Nancy Ajram to Elissa: I hope for urgent healing .. The latter reassures its audience Gold prices on Saturday 16 -2-2019 in the markets Pictures The head of the Munich conference is delaying the ruling on the resumption of Dalia El Beheiry's sentence of imprisonment for two years April 6 Military spokesman: the elimination of 7 Takfirin in North Sinai Gold prices climb World of the highest level in the two weeks The Times: The bride of the "Islamic State" afraid of her child and reveal her love for her jihadist husband Formation of the expected Ahli .. Nasser Maher essential to the production of war 10 ways protect your cells from the transformation of cancer .. Known as the death of the accused «storming the Assiut mosque »In the exchange of fire with the police wind Airport and coldness at night .. Meteorology announces the details of weather Saturday Saturday .. Government launches an early detection of obesity and stunting schools Samsung unveils its Tablet PC Galaxy Tab S5e thickness of 5.5 mm only 01:02 Your luck today .. Predictions Towers Saturday, February 16 2019 Surprise. Khashoggi assassination team bought 32 kg of raw meat after the crime Your luck on Saturday 16/2/2019 Tower of lion in the professional, healthy and emotional .. Good luck these days
# countries_words updated with Egypt words for 2019-02-16
# -----------------------------------------------------------
# France
# https://newsapi.org/v2/top-headlines?country=fr&apiKey=89f29e52b3ff48fbbdb6b5439cf0fba4
# TITLES::::::
# Championnats du monde: le titre du slalom pour Shiffrin
# countries_data updated with France data.
# Fourgon volé à Aubervilliers: Le convoyeur et une complice présumée présentés à un juge
# countries_data updated with France data.
# Retraites: Delevoye veut réformer l'actuel système d'indexation des salaires
# countries_data updated with France data.
# Jennifer Aniston et Courteney Cox : Frayeur en avion, atterrissage d'urgence
# countries_data updated with France data.
# Bruno Ganz : Mort de l'acteur suisse à l'âge de 77 ans
# countries_data updated with France data.
# Mercato | Mercato
# countries_data updated with France data.
# En Sibérie, de la neige noire recouvre plusieurs villes
# countries_data updated with France data.
# Syrie : le dernier bastion de l'Etat Islamique sur le point de tomber
# countries_data updated with France data.
# «Acte 14» des «Gilets jaunes»: des milliers de manifestants défilent à nouveau
# countries_data updated with France data.
# Nerf : Une gamme de jouets Fortnite s'invite chez Hasbro
# countries_data updated with France data.
# Au Japon, Carlos Ghosn opte pour une stratégie de défense plus offensive
# countries_data updated with France data.
# Accusé d'abus sexuels, l'ex-cardinal McCarrick défroqué par le Vatican, une première
# countries_data updated with France data.
# 🔥 Soldes Amazon : 7 promos High-tech exclusives à découvrir ce week-end
# countries_data updated with France data.
# Brock James (UBB), Clermont au coeur
# countries_data updated with France data.
# Audiences : Succès pour le "Palmashow" sur TF1, "Chérif" 2e, Patrick Sabatier faible sur C8
# countries_data updated with France data.
# Galaxy S10, Galaxy F... Ce qu'il faut attendre de la conférence Unpacked de Samsung
# countries_data updated with France data.
# Jenifer (The Voice): «Julien Clerc prend son rôle de coach très à cœur»
# countries_data updated with France data.
# Bar-le-Duc : visite surprise de Brigitte Macron au théâtre des Bleus de Bar
# countries_data updated with France data.
# Wall Street portée par les espoirs sur le commerce
# countries_data updated with France data.
# Nigeria : 66 morts dans des violences communautaires à la veille de la présidentielle
# countries_data updated with France data.
# France failed to translate
# -----------------------------------------------------------
# Germany
# https://newsapi.org/v2/top-headlines?country=de&apiKey=89f29e52b3ff48fbbdb6b5439cf0fba4
# TITLES::::::
# Bundesliga: Schalke will Befreiungsschlag gegen Freiburg |Live
# countries_data updated with Germany data.
# Sicherheitskonferenz: US-Vize Pence warnt Deutschland wegen "Nord Stream 2"
# countries_data updated with Germany data.
# FC Bayern München: Hasan Salihamidzic faltet Abwehr-Stümper zusammen
# countries_data updated with Germany data.
# Merkel auf der Sicherheitskonferenz
# countries_data updated with Germany data.
# ...
# Пенсії зростуть: в уряді нагадали, коли і на скільки
# countries_data updated with Ukraine data.
# Промоутер Усика планує організувати бій українця з черговим росіянином | Бокс
# countries_data updated with Ukraine data.
# З явилися подробиці стрілянини в американській компанії
# countries_data updated with Ukraine data.
# У відповідь на ворожі обстріли бійці ООС знищили сімох окупантів
# countries_data updated with Ukraine data.
# NASA попрощалося з легендарним марсоходом Opportunity: останні фото і відео
# countries_data updated with Ukraine data.
# Надзвичайна ситуація в США та нові американські кошти для України. П’ять новин які ви могли проспати
# countries_data updated with Ukraine data.
# У НАТО готуються до російських ракет у Європі
# countries_data updated with Ukraine data.
# Динамо – Олімпіакос: Сабо зробив прогноз на матч у Києві — Футбол 24
# countries_data updated with Ukraine data.
# Прокляття другої стрільби: всі подробиці чоловічого спринту 8-го етапу Кубка світу з біатлону
# countries_data updated with Ukraine data.
# Яркое автошоу в Чикаго. Пять уникальных премьер | Korrespondent.net
# countries_data updated with Ukraine data.
# Скандал на нацвідборі на «Євробачення»: канал-транслятор не покаже виступи перших учасників
# countries_data updated with Ukraine data.
# Найшвидший у світі: Bentley представила свій новий кросовер (фотогалерея, відео)
# countries_data updated with Ukraine data.
# Samsung Galaxy S10
# countries_data updated with Ukraine data.
# Лукашенко об объединении с РФ: Независимость
# countries_data updated with Ukraine data.
# Маша Єфросиніна показала інтимне фото з чоловіком
# countries_data updated with Ukraine data.
# TRANSLATED::::::
# Ukraine
# Klimkin said when Russia to wait for personal sanctions from EU Ulyana Suprun: why not appoint a health minister Astronomers fix flash star in billions of times brighter than the Sun Poroshenko and Merkel discussed opposition to Russian intervention in the election Merkel opposed the isolation of Russia Pensions will grow: in the government reminded when and how much Promoter Usika plans to organize a fight Ukrainian with another Russian | Boxing C revealed details of firing in an American company In response to hostile shelling, Fighters fired seven invaders NASA farewell to the legendary rover Opportunity: recent photos and videos Emergency situation in the US and new US funds for Ukraine. Five news stories you could sleep on In NATO, preparing for Russian missiles in Europe Dynamo - Olympiacos: Sabo made a prediction on the match in Kiev - Football 24 Curse of the second shooting: all details of the male sprint of the 8th stage of the World Cup on biathlon Bright auto show in Chicago . Five unique prime | Korrespondent.net A scandal at the national election for Eurovision: the broadcaster will not show the performances of the first participants The fastest in the world: Bentley introduced its new crossover (photo gallery, video) Samsung Galaxy S10 Lukashenka to unite with Russia: Independence Masha Efrosinin showed an intimate photo with her husband
# countries_words updated with Ukraine words for 2019-02-16
# -----------------------------------------------------------
# United Kingdom
# https://newsapi.org/v2/top-headlines?country=gb&apiKey=89f29e52b3ff48fbbdb6b5439cf0fba4
# TITLES::::::
# Bruno Ganz, actor who played Hitler in Downfall, dies aged 77
# countries_data updated with United Kingdom data.
# Prince Harry 'racked up £30,000 bill' on Las Vegas party trip
# countries_data updated with United Kingdom data.
# Pope Francis defrocks ex US cardinal Theodore McCarrick known as 'Uncle Ted' to the young men he sought for sex abuse
# countries_data updated with United Kingdom data.
# 'Killer' child car seats sold online even though they're illegal
# countries_data updated with United Kingdom data.
# Ant McPartlin slams Piers Morgan for 'belittling' his rehab battle
# countries_data updated with United Kingdom data.
# Police search for missing couple after their crashed car was found empty
# countries_data updated with United Kingdom data.
# Girl must live with strangers instead of her grandparents because they can’t meet her emotional needs, judge r
# countries_data updated with United Kingdom data.
# We Dissected Super Mario Maker 2's Trailer With The Help Of An Expert
# countries_data updated with United Kingdom data.
# Teeth can be used to predict mental health problems
# countries_data updated with United Kingdom data.
# Paul Hollywood’s ex-wife denies verbally abusing baker’s new partner
# countries_data updated with United Kingdom data.
# UK cannot make Islamic State bride stateless, justice secretary admits
# countries_data updated with United Kingdom data.
# Birmingham college stabbing: Student dies in hospital
# countries_data updated with United Kingdom data.
# Jihadi bride Shamima Begum who fled UK describes the 'best part' of living under ISIS
# countries_data updated with United Kingdom data.
# Venezuela’s opposition reaches out to Russia and China
# countries_data updated with United Kingdom data.
# Chelsea news: Don’t just blame Sarri! Six big systemic problems the Blues have
# countries_data updated with United Kingdom data.
# BREXIT LIVE: BREAKTHROUGH? Paris BLINKS FIRST as Macron set to concede over Irish backstop
# countries_data updated with United Kingdom data.
# Arsenal transfer news: Mesut Ozil appears to send message to Unai Emery in cryptic Twitter post
# countries_data updated with United Kingdom data.
# The midlife guide to interval training: how to get fit in 23 minutes... without hurting yourself
# countries_data updated with United Kingdom data.
# Nigeria delays presidential election for a week amid 'challenges'
# countries_data updated with United Kingdom data.
# Ryanair passengers get double the time to alter bookings for free
# countries_data updated with United Kingdom data.
# TRANSLATED::::::
# United Kingdom
# Bruno Ganz, actor who played Hitler in Downfall, dies aged 77 Prince Harry 'racked up £30,000 bill' on Las Vegas party trip Pope Francis defrocks ex US cardinal Theodore McCarrick known as 'Uncle Ted' to the young men he sought for sex abuse 'Killer' child car seats sold online even though they're illegal Ant McPartlin slams Piers Morgan for 'belittling' his rehab battle Police search for missing couple after their crashed car was found empty Girl must live with strangers instead of her grandparents because they can’t meet her emotional needs, judge r We Dissected Super Mario Maker 2's Trailer With The Help Of An Expert Teeth can be used to predict mental health problems Paul Hollywood’s ex-wife denies verbally abusing baker’s new partner UK cannot make Islamic State bride stateless, justice secretary admits Birmingham college stabbing: Student dies in hospital Jihadi bride Shamima Begum who fled UK describes the 'best part' of living under ISIS Venezuela’s opposition reaches out to Russia and China Chelsea news: Don’t just blame Sarri! Six big systemic problems the Blues have BREXIT LIVE: BREAKTHROUGH? Paris BLINKS FIRST as Macron set to concede over Irish backstop Arsenal transfer news: Mesut Ozil appears to send message to Unai Emery in cryptic Twitter post The midlife guide to interval training: how to get fit in 23 minutes... without hurting yourself Nigeria delays presidential election for a week amid 'challenges' Ryanair passengers get double the time to alter bookings for free
# countries_words updated with United Kingdom words for 2019-02-16
# -----------------------------------------------------------
# United States of America
# https://newsapi.org/v2/top-headlines?country=us&apiKey=89f29e52b3ff48fbbdb6b5439cf0fba4
# TITLES::::::
# Man kills five in warehouse shooting spree shortly after being fired, Illinois police say
# countries_data updated with United States of America data.
# Vatican Defrocks Former Cardinal McCarrick, Finds Him Guilty Of Sex Abuse
# countries_data updated with United States of America data.
# Elon Musk says SpaceX is developing a 'bleeding' heavy-metal rocket ship. Making it work may be 100 times as hard as NASA's most difficult Mars mission, one expert says.
# countries_data updated with United States of America data.
# Washington state House committee passes bill to ban personal, philosophical vaccine exemptions | TheHill
# countries_data updated with United States of America data.
# Oscars reverses hugely unpopular decision after backlash from Brad Pitt, George Clooney and more
# countries_data updated with United States of America data.
# The Morning After: Amazon drops 'LotR' hints
# countries_data updated with United States of America data.
# Payless ShoeSource is closing all of its 2100 remaining U.S. stores
# countries_data updated with United States of America data.
# Amazon’s HQ2 New York plans didn’t need to end this way
# countries_data updated with United States of America data.
# From Echo to Ring doorbell and Fire TV, are you comfortable Amazon controlling your smart home?
# countries_data updated with United States of America data.
# Ben Simmons Puts Up 28 Points & 6 Assists In Rising Stars Game | 2019 NBA All-Star
# countries_data updated with United States of America data.
# Space Photos of the Week: The Trail of Opportunity and More
# countries_data updated with United States of America data.
# In Munich, Pence doubles down on criticism of Europe over Iran nuclear deal, urges removal of Maduro
# countries_data updated with United States of America data.
# Matt Kuchar apologizes, will pay $50G to caddie after being accused of being a cheapskate
# countries_data updated with United States of America data.
# ISIS now controls just 700 square meters in Syria, says SDF
# countries_data updated with United States of America data.
# Iran warns Pakistan to crack down on Jaish al-Adl
# countries_data updated with United States of America data.
# 'I didn't need to do this.' Critics say Trump quote undercuts national emergency for border wall
# countries_data updated with United States of America data.
# AirPods, iPads and streaming: What we could see from a March Apple event
# countries_data updated with United States of America data.
# Deer in 24 states infected with chronic wasting disease
# countries_data updated with United States of America data.
# Bruno Ganz, who played Hitler in Downfall, dies aged 77
# countries_data updated with United States of America data.
# Amazon invites Ocasio-Cortez to ‘see for yourself’ after she slams ‘dehumanizing’ working conditions
# countries_data updated with United States of America data.
# TRANSLATED::::::
# United States of America
# Man kills five in warehouse shooting spree shortly after being fired, Illinois police say Vatican Defrocks Former Cardinal McCarrick, Finds Him Guilty Of Sex Abuse Elon Musk says SpaceX is developing a 'bleeding' heavy-metal rocket ship. Making it work may be 100 times as hard as NASA's most difficult Mars mission, one expert says. Washington state House committee passes bill to ban personal, philosophical vaccine exemptions | TheHill Oscars reverses hugely unpopular decision after backlash from Brad Pitt, George Clooney and more The Morning After: Amazon drops 'LotR' hints Payless ShoeSource is closing all of its 2100 remaining U.S. stores Amazon’s HQ2 New York plans didn’t need to end this way From Echo to Ring doorbell and Fire TV, are you comfortable Amazon controlling your smart home? Ben Simmons Puts Up 28 Points & 6 Assists In Rising Stars Game | 2019 NBA All-Star Space Photos of the Week: The Trail of Opportunity and More In Munich, Pence doubles down on criticism of Europe over Iran nuclear deal, urges removal of Maduro Matt Kuchar apologizes, will pay $50G to caddie after being accused of being a cheapskate ISIS now controls just 700 square meters in Syria, says SDF Iran warns Pakistan to crack down on Jaish al-Adl 'I didn't need to do this.' Critics say Trump quote undercuts national emergency for border wall AirPods, iPads and streaming: What we could see from a March Apple event Deer in 24 states infected with chronic wasting disease Bruno Ganz, who played Hitler in Downfall, dies aged 77 Amazon invites Ocasio-Cortez to ‘see for yourself’ after she slams ‘dehumanizing’ working conditions
# countries_words updated with United States of America words for 2019-02-16
# -----------------------------------------------------------
# Venezuela
# https://newsapi.org/v2/top-headlines?country=ve&apiKey=89f29e52b3ff48fbbdb6b5439cf0fba4
# TITLES::::::
# Nueva investigación revela montañas a 660 kilómetros bajo tierra
# countries_data updated with Venezuela data.
# Siga en vivo la juramentación de #VoluntariosXVenezuela
# countries_data updated with Venezuela data.
# La desconfianza en vacunas desata un grave brote de sarampión en Filipinas
# countries_data updated with Venezuela data.
# Maduro llama a militares a preparar despliegue en la frontera
# countries_data updated with Venezuela data.
# Presidente de la ANC de Venezuela asegura que la oposición es agente de EE.UU.
# countries_data updated with Venezuela data.
# Valor del petróleo alcanzó su nivel más alto desde noviembre del pasado año
# countries_data updated with Venezuela data.
# Unión Europea discutirá planes para aplicar más presión a Maduro
# countries_data updated with Venezuela data.
# 6 cosas que puede hacer tu celular y que tal vez no sabías
# countries_data updated with Venezuela data.
# Juventus se recrea ante el Frosinone con Cristiano Ronaldo en plan grande
# countries_data updated with Venezuela data.
# Continúan protestas en Haití tras discurso del presidente Jovenel Moise
# countries_data updated with Venezuela data.
# Precio de cinco criptoactivos cae tras anuncio de su retiro de Binance
# countries_data updated with Venezuela data.
# Embajador de Venezuela ante la OEA: Para sacarnos de aquí deben cumplir con los 24 votos
# countries_data updated with Venezuela data.
# Motín en Hollywood contra la entrega de Óscar durante los anuncios
# countries_data updated with Venezuela data.
# Cuerpo de Emiliano Sala llegó a Argentina para funeral y homenajes
# countries_data updated with Venezuela data.
# Ex Miss Universo sufre aparatosa caída en programa en vivo
# countries_data updated with Venezuela data.
# ONU prestará apoyo a Venezuela con la compra de medicinas e insumos
# countries_data updated with Venezuela data.
# Una brasileña se queda en silla de ruedas por hacerse un piercing en la nariz
# countries_data updated with Venezuela data.
# Maduro: Venezuela se está jugando su derecho a la paz
# countries_data updated with Venezuela data.
# Astronomy & Astrophysics: Un río de estrellas se hace patente en el vecindario solar
# countries_data updated with Venezuela data.
# Renovación, futuro, Rakitic, De Jong... Ernesto Valverde se pronuncia
# countries_data updated with Venezuela data.
# TRANSLATED::::::
# Venezuela
# New research reveals mountains 660 kilometers underground Follow live swearing of #VoluntariosXVenezuela Vaccine distrust unleashes a serious outbreak of measles in the Philippines Maduro calls military to prepare deployment on the border President of the ANC of Venezuela ensures that the opposition is US agent Value of oil reached its highest level since November of last year European Union will discuss plans to apply more pressure to Maduro 6 things that your cell phone can do and that maybe you did not know Juventus recreates before the Frosinone with Cristiano Ronaldo in big plan Continues protests in Haiti after President Jovenel Moise's speech Price of five cryptoactives falls after announcement of his retirement from Binance Ambassador of Venezuela to the OAS: To get us out of here they must comply with the 24 votes Riot in Hollywood against the delivery of Oscar during the announcements Body of Emiliano Sala arrived in Argentina for funeral and tributes Ex Miss Universe suffers spectacular fall in live program UN will lend support to Venezuela with the purchase of medicines and supplies A Brazilian woman stays in a wheelchair for piercing her nose Maduro: Venezuela is playing its right to peace Astronomy & Astrophysics: A river of stars is evident in the neighborhood Lar Renovation, future, Rakitic, De Jong ... Ernesto Valverde pronounces
# countries_words updated with Venezuela words for 2019-02-16

# %%
# ####remove articles added to keywords collection
# collection = db["countries_keywords"]
# collection.update_many({}, {'$unset': {'articles':1}}, multi=True)

# %%
# # ### reset data
# collection = db["country_data"]

# # for i in range(len(country_codes)):
# print("Argentina")
# badList = data[0]["articles"]
# goodList = []
# for i in range(40):
#     goodList.append(badList[i])
# print(len(goodList))
# collection.insert({"country": "AAAAAAAAAAA"}, {"$set": {"articles": goodList}})
# # collection.update_one({"country": countries[i]}, {"$set": {"keywords": keywords_dict["keywords"]}}, upsert=True)
# print(len(data[0]["articles"]))

# %%
response = requests.get(f"https://newsapi.org/v2/top-headlines?country=us&apiKey={API_KEY}").json()

# %%
response
# Out:
# {'status': 'error',
#  'code': 'rateLimited',
#  'message': 'You have made too many requests recently. Developer accounts are limited to 1,000 requests over a 24 hour period (250 requests available every 6 hours). Please upgrade to a paid plan if you need more requests.'}
